# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
import dateutil.parser as parser

# %%
## Import the dataset
url = 'TimeSeries.csv'
dusaf_df = pd.read_csv(url)

# %% [markdown]
# #### Transpoze the dataset

# %%
dusaf_T= dusaf_df.T
## Check the types
print(dusaf_T.dtypes)
# Out:
# 0       object
# 1       object
# 2       object
# 3       object
# 4       object
#          ...
# 1023    object
# 1024    object
# 1025    object
# 1026    object
# 1027    object
# Length: 1028, dtype: object

# %%
Last_2rows = dusaf_T.tail(2)
First_row = dusaf_T.head(1)
print(Last_2rows)
print(First_row)
# Out:
#                                                    0     \
# fid                                                  30
# .geo  {"type":"Polygon","coordinates":[[[8.630490880...
#
#                                                    1     \
# fid                                                  31
# .geo  {"type":"GeometryCollection","geometries":[{"t...
#
#                                                    2     \
# fid                                                1009
# .geo  {"type":"Polygon","coordinates":[[[8.929569012...
#
#                                                    3     \
# fid                                                  74
# .geo  {"type":"Polygon","coordinates":[[[8.686038936...
#
#                                                    4     \
# fid                                                  75
# .geo  {"type":"Polygon","coordinates":[[[8.667238902...
#
#                                                    5     \
# fid                                                 101
# .geo  {"type":"Polygon","coordinates":[[[9.233289853...
#
#                                                    6     \
# fid                                                 102
# .geo  {"type":"Polygon","coordinates":[[[9.763820142...
#
#                                                    7     \
# fid                                                 103
# .geo  {"type":"Polygon","coordinates":[[[9.536254309...
#
#                                                    8     \
# fid                                                 168
# .geo  {"type":"GeometryCollection","geometries":[{"t...
#
#                                                    9     ...  \
# fid                                                1006  ...
# .geo  {"type":"Polygon","coordinates":[[[8.672664853...  ...
#
#                                                    1018  \
# fid                                                  12
# .geo  {"type":"Polygon","coordinates":[[[9.368104931...
#
#                                                    1019  \
# fid                                                 109
# .geo  {"type":"Polygon","coordinates":[[[10.99194946...
#
#                                                    1020  \
# fid                                                  14
# .geo  {"type":"Polygon","coordinates":[[[9.434559174...
#
#                                                    1021  \
# fid                                                 534
# .geo  {"type":"Polygon","coordinates":[[[10.48566588...
#
#                                                    1022  \
# fid                                                  43
# .geo  {"type":"Polygon","coordinates":[[[9.422091083...
#
#                                                    1023  \
# fid                                                  46
# .geo  {"type":"MultiPolygon","coordinates":[[[[9.233...
#
#                                                    1024  \
# fid                                                  54
# .geo  {"type":"Polygon","coordinates":[[[9.347620406...
#
#                                                    1025  \
# fid                                                  55
# .geo  {"type":"Polygon","coordinates":[[[9.289867537...
#
#                                                    1026  \
# fid                                                  56
# .geo  {"type":"Polygon","coordinates":[[[9.291465176...
#
#                                                    1027
# fid                                                 953
# .geo  {"type":"Polygon","coordinates":[[[9.294370020...
#
# [2 rows x 1028 columns]
#                                                            0     \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            1     \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            2     \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            3     \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            4     \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            5     \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            6     \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            7     \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            8     \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            9     ...  \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...  ...
#
#                                                            1018  \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            1019  \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            1020  \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            1021  \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            1022  \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            1023  \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            1024  \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            1025  \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            1026  \
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
#                                                            1027
# system:index  20190102T102429_20190102T102505_T32TMQ_0000000...
#
# [1 rows x 1028 columns]

# %%
dusaf_T.drop(dusaf_T.tail(2).index,
        inplace = True)
dusaf_T.drop(dusaf_T.head(1).index,
        inplace = True)

# %%
Date_as_column = dusaf_T.reset_index(level=0)
index = 0
for row in dusaf_T.itertuples():
    Date_as_column.at[index,'index']= parser.parse(row[0])

    print(row[0])
    index += 1
